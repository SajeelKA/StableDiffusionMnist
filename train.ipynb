# %%
import sys
import os
from datetime import datetime

from google.colab import drive
drive.mount('/content/drive', force_remount=True)

if '/content/drive/MyDrive/allRepos/StableDiffusionMnist/' not in sys.path:# try with and without '/' at the end
  sys.path.append('/content/drive/MyDrive/allRepos/StableDiffusionMnist') # try with and without '/' at the end
# Out:
# Mounted at /content/drive

# %% [markdown]
#   # PARAMETER LIST TO RUN BELOW CELL
#
#   ### "--batchSize", required = False, type=int, default = 32
#
#   ### "--learningRate", required = False, type=float, default = 1e-4
#
#   ### "--epochs", required = False, type=int, default = 10
#
#   ### "--latentEmbedChannels", required = False, type=int, default = 4
#
#   ### "--textEmbedChannels", required = False, type=int, default = 16
#
#   ### "--timeSteps", required = False, type=int, default = 300
#
#   ### "--usedProcessor", required = False, default = 'cpu'
#
#   ### "--savePath", required = True, default = None

# %%
# !python "/content/drive/MyDrive/allRepos/StableDiffusionMnist/train.py" --savePath "/content/drive/MyDrive/allRepos/StableDiffusionMnist/savedModels/"
