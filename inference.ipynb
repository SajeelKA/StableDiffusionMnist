# %%
import sys
import os
from datetime import datetime
from google.colab import drive
drive.mount('/content/drive', force_remount=True)

if '/content/drive/MyDrive/allRepos/StableDiffusionMnist/' not in sys.path:# try with and without '/' at the end
  sys.path.append('/content/drive/MyDrive/allRepos/StableDiffusionMnist') # try with and without '/' at the end
# Out:
# Mounted at /content/drive

# %% [markdown]
#   # PARAMETER LIST TO RUN BELOW CELL
#
#   ### "--fileName", required = False, type=int, default = 'testStableDiffusion.pth'
#
#   ### "--digit", required = False, type=float, default = 3
#
#   ### "--rootDir", required = False, default = '/content/drive/MyDrive/allRepos/Diffusion/'
#
#   ### "--batchSize", required = False, type=int, default = 4
#
#   ### "--EmbedChannels", required = False, type=int, default = 16
#
#   ### "--timeSteps", required = False, type=int, default = 300
#
#   ### "--conditionalScale", required = False, type=float, default = 5.0

# %%
# !python "/content/drive/MyDrive/allRepos/StableDiffusionMnist/inference.py" --digit 3
# Out:
# loading from:  /content/drive/MyDrive/allRepos/Diffusion/savedModels/testStableDiffusion.pth
# figure saved to:  /content/drive/MyDrive/allRepos/Diffusion/images/result3.png
